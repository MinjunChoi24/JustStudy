# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime

# %%
data = pd.read_csv('data_4517_20260116.csv',encoding='CP949',dtype=str)

# %%
corp_code = data['corp_code']
corp_code.dropna(inplace=True)

# %%
start = "2025-06-01"
end = "2026-01-30"

Kospi_prices = yf.download('^KS11',start=start,end=end)['Close']['^KS11']

weekly_return1 = Kospi_prices.pct_change(periods=5)[5:] * 100 

weekly_return1.dropna(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def RS_week(ticker):

    try:
        ETF_prices = yf.download(f'{ticker}.KS',start=start,end=end)['Close'][f'{ticker}.KS']
        
        weekly_return2 = ETF_prices.pct_change(periods=5)[5:] * 100

        weekly_return2.dropna(inplace=True)

        RS = weekly_return2 - weekly_return1

        return RS,ticker
    
    except:
        print(ticker)

# %%
corp_list = []
today_str = datetime.now().strftime('%Y-%m-%d')

for i in corp_code:
    st,ticker = RS_week(i)
    if ticker:
        if st[-1]>=0:
            corp_list.append(ticker)

df = pd.DataFrame(corp_list,columns=['corp_list'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# ...
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\AppData\Local\Temp\ipykernel_51336\1702401218.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if st[-1]>=0:

# %%
file_name = f'sep_corp_list_{today_str}.xlsx'

df.to_csv(file_name, index=False)
print(f"✅ {file_name} 파일 생성 및 저장 완료!")
# Out:
# ✅ sep_corp_list_2026-01-21.xlsx 파일 생성 및 저장 완료!
