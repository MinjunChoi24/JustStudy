# %%
import numpy as np

np.random.seed(121)

# %%
X = np.random.randint(100,size=20)

X = np.sort(X)
print(f'X: {X}')

mu = np.mean(X)
print('Mean of X:', mu)
# Out:
# X: [ 3  8 34 39 46 52 52 52 54 57 60 65 66 75 83 85 88 94 95 96]
# Mean of X: 60.2

# %% [markdown]
# # Range

# %%
print(f'Range of X: {np.ptp(X)}')
# Out:
# Range of X: 93

# %% [markdown]
# # Mean Absolute Deviation (MAD)

# %%
abs_dispersion = [np.abs(mu-X)]
MAD = np.sum(abs_dispersion)/len(abs_dispersion)
print('Mean absolute deviation of X:',MAD)
# Out:
# Mean absolute deviation of X: 23.95

# %% [markdown]
# # Variance and standard deviation

# %%
print('Variance of X:',np.var(X))
print('Standard deviation of X:',np.std(X))
# Out:
# Variance of X: 670.16
# Standard deviation of X: 25.887448696231154

# %%
k=1.25
dist = k*np.std(X)
l = [x for x in X if (abs(x-mu)<=dist)]
print('Observations within',k,'stds of mean:',l)
print('Confirming that',float(len(l))/len(X),'>',1-1/k**2)
# Out:
# Observations within 1.25 stds of mean: [np.int32(34), np.int32(39), np.int32(46), np.int32(52), np.int32(52), np.int32(52), np.int32(54), np.int32(57), np.int32(60), np.int32(65), np.int32(66), np.int32(75), np.int32(83), np.int32(85), np.int32(88)]
# Confirming that 0.75 > 0.36

# %% [markdown]
# # Semivariance and semideviation

# %%
lows = [e for e in X if e <= mu]

semivar = np.sum((lows-mu)**2)/len(lows)

print('Semivarience of X:',semivar)
print('Semideviation of X:',np.sqrt(semivar))
# Out:
# Semivarience of X: 689.5127272727273
# Semideviation of X: 26.258574357202395

# %% [markdown]
# # 목표 분산(Target Variance) 및 목표 반표준편차(Target Semi-deviation)

# %%
B=19
lows_B = [e for e in X if e <= B]
semivar_B = sum(map(lambda x : (x-B)**2,lows_B))/len(lows_B)

print('Target semivarience of X:', semivar_B)
print('Target semideviation of X:', np.sqrt(semivar_B))
# Out:
# Target semivarience of X: 188.5
# Target semideviation of X: 13.729530217745982
